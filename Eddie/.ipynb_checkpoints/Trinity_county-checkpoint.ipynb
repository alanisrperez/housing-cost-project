# %%
import pandas as pd

# Load the .xls Excel file
TrinityCounty = pd.read_excel("Resources/TRINIHWS.xls", engine='xlrd')

TrinityCounty.head()
# Out:
#    SORTORDER  BMYEAR  AREA               INCLUDES  BREAKS  PNCO   SS-NAICS  \
# 0          1    2023   105                    NaN     NaN     1  00-000010
# 1          2    2023   105                    NaN     NaN     1  00-000020
# 2          3    2023   105                    NaN     NaN     1  00-000030
# 3          4    2023   105                    NaN     NaN     1  00-000040
# 4          8    2023   105  110000-813000, 920000     NaN     1  01-000000
#
#                         TITLE  2010-01-01 00:00:00  2010-02-01 00:00:00  ...  \
# 0        Civilian Labor Force             5250.000              5320.00  ...
# 1         Civilian Employment             4150.000              4200.00  ...
# 2       Civilian Unemployment             1090.000              1120.00  ...
# 3  Civilian Unemployment Rate                0.208                 0.21  ...
# 4       Total, All Industries             2520.000              2540.00  ...
#
#    2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00  \
# 0              4600.00             4550.000             4510.000
# 1              4370.00             4310.000             4250.000
# 2               230.00              240.000              270.000
# 3                 0.05                0.052                0.059
# 4              3050.00             3010.000             2990.000
#
#    2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00  \
# 0             4530.000             4600.000             4650.000
# 1             4180.000             4250.000             4310.000
# 2              350.000              360.000              330.000
# 3                0.076                0.078                0.072
# 4             2880.000             2930.000             2970.000
#
#    2024-04-01 00:00:00  2024-05-01 00:00:00  2024-06-01 00:00:00  \
# 0             4520.000             4620.000             4790.000
# 1             4230.000             4400.000             4540.000
# 2              290.000              230.000              250.000
# 3                0.064                0.049                0.052
# 4             2950.000             3090.000             3240.000
#
#    2024-07-01 00:00:00
# 0             4800.000
# 1             4530.000
# 2              270.000
# 3                0.056
# 4             3200.000
#
# [5 rows x 183 columns]

# %%
TrinityCounty.drop(['SORTORDER', 'BMYEAR', 'AREA', 'INCLUDES', 'BREAKS', 'PNCO', 'SS-NAICS'], axis=1, inplace=True)

TrinityCounty.head()
# Out:
#                         TITLE  2010-01-01 00:00:00  2010-02-01 00:00:00  \
# 0        Civilian Labor Force             5250.000              5320.00
# 1         Civilian Employment             4150.000              4200.00
# 2       Civilian Unemployment             1090.000              1120.00
# 3  Civilian Unemployment Rate                0.208                 0.21
# 4       Total, All Industries             2520.000              2540.00
#
#    2010-03-01 00:00:00  2010-04-01 00:00:00  2010-05-01 00:00:00  \
# 0               5360.0             5360.000             5450.000
# 1               4280.0             4370.000             4570.000
# 2               1070.0              990.000              880.000
# 3                  0.2                0.185                0.162
# 4               2590.0             2660.000             2830.000
#
#    2010-06-01 00:00:00  2010-07-01 00:00:00  2010-08-01 00:00:00  \
# 0             5660.000             5630.000             5660.000
# 1             4790.000             4760.000             4840.000
# 2              870.000              860.000              820.000
# 3                0.154                0.153                0.145
# 4             3000.000             2940.000             3010.000
#
#    2010-09-01 00:00:00  ...  2023-10-01 00:00:00  2023-11-01 00:00:00  \
# 0             5500.000  ...              4600.00             4550.000
# 1             4690.000  ...              4370.00             4310.000
# 2              810.000  ...               230.00              240.000
# 3                0.148  ...                 0.05                0.052
# 4             2910.000  ...              3050.00             3010.000
#
#    2023-12-01 00:00:00  2024-01-01 00:00:00  2024-02-01 00:00:00  \
# 0             4510.000             4530.000             4600.000
# 1             4250.000             4180.000             4250.000
# 2              270.000              350.000              360.000
# 3                0.059                0.076                0.078
# 4             2990.000             2880.000             2930.000
#
#    2024-03-01 00:00:00  2024-04-01 00:00:00  2024-05-01 00:00:00  \
# 0             4650.000             4520.000             4620.000
# 1             4310.000             4230.000             4400.000
# 2              330.000              290.000              230.000
# 3                0.072                0.064                0.049
# 4             2970.000             2950.000             3090.000
#
#    2024-06-01 00:00:00  2024-07-01 00:00:00
# 0             4790.000             4800.000
# 1             4540.000             4530.000
# 2              250.000              270.000
# 3                0.052                0.056
# 4             3240.000             3200.000
#
# [5 rows x 176 columns]

# %%
titles_df = TrinityCounty["TITLE"]
titles_df
# Out:
# 0                            Civilian Labor Force
# 1                             Civilian Employment
# 2                           Civilian Unemployment
# 3                      Civilian Unemployment Rate
# 4                           Total, All Industries
# 5                                      Total Farm
# 6                                   Total Nonfarm
# 7                                   Total Private
# 8                                 Goods Producing
# 9                Mining, Logging and Construction
# 10                                  Manufacturing
# 11                              Service-Providing
# 12           Private Service Providing - Residual
# 13           Trade, Transportation, and Utilities
# 14                           Financial Activities
# 15          Private Education and Health Services
# 16                        Leisure and Hospitality
# 17                                     Government
# 18                             Federal Government
# 19               Total State and Local Government
# 20                               State Government
# 21                               Local Government
# Name: TITLE, dtype: object

# %%
# Create an empty DataFrame to store the averages for each year
averaged_years_df = pd.DataFrame()

# Loop through each year from 2010 to 2024
for year in range(2010, 2025):
    # Adjust the column range based on your DataFrame structure
    # Replace '1:13' with the actual column range for each year
    start_col = (year - 2010) * 12 + 1  # Adjust column index logic as per your DataFrame structure
    end_col = start_col + 12
    
    # Select the columns for the current year
    columns_for_year = TrinityCounty.iloc[:, start_col:end_col]
    
    # Calculate the row-wise average for these columns and round to 2 decimal places
    TrinityCounty[f'{year}_Average'] = columns_for_year.mean(axis=1).round(2)
    
    # Add the year and its average column to the new DataFrame
    averaged_years_df[f'{year}_Average'] = TrinityCounty[f'{year}_Average']

# Add the 'TITLE' column to the new DataFrame
averaged_years_df['TITLE'] = TrinityCounty['TITLE']

# Reorder columns to put 'TITLE' at the front
averaged_years_df = averaged_years_df[['TITLE'] + [col for col in averaged_years_df.columns if col != 'TITLE']]

# Print or inspect the new DataFrame with averages from 2010 to 2024 and the TITLE column
# 9          77.50         87.50         91.67        106.67        111.67
# 10        219.17        200.83        195.83        196.67        193.33
# 11       2628.33       2584.17       2625.00       2490.83       2559.17
# 12        250.00        237.50        260.83        263.33        257.50
# 13        423.33        363.33        373.33        370.83        392.50
# 14         47.50         41.67         43.33         40.00         45.00
# 15        271.67        278.33        281.67        270.83        238.33
# 16        338.33        341.67        340.00        270.00        312.50
# 17       1300.83       1320.83       1331.67       1280.00       1318.33
# 18        231.67        215.00        211.67        214.17        204.17
# 19       1071.67       1105.83       1118.33       1065.00       1112.50
# 20        102.50        108.33        110.00        110.00        104.17
# 21        967.50        999.17       1009.17        957.50       1008.33
#
#     2022_Average  2023_Average  2024_Average
# 0        4516.67       4560.00       4916.18
# 1        4303.33       4300.83       4429.38
# 2         211.67        260.00        487.36
# 3           0.05          0.06          0.10
# 4        2945.83       2967.50       2952.78
# 5          30.00         29.17         28.61
# 6        2915.83       2938.33       2924.17
# 7        1559.17       1562.50       1516.88
# 8         290.00        270.83        274.79
# 9         110.83         93.33        100.35
# 10        180.83        179.17        178.61
# 11       2625.00       2667.50       2647.71
# 12        265.00        249.17        213.75
# 13        385.83        365.83        362.71
# 14         41.67         40.00         45.76
# 15        236.67        256.67        256.94
# 16        340.00        380.83        362.92
# 17       1360.00       1375.83       1408.12
# 18        197.50        203.33        220.00
# 19       1159.17       1171.67       1188.96
# 20        104.17         98.33        112.22
# 21       1056.67       1078.33       1077.57

# %%
averaged_years_df.head()
# Out:
#                         TITLE  2010_Average  2011_Average  2012_Average  \
# 0        Civilian Labor Force       5438.33       5383.33       5325.00
# 1         Civilian Employment       4490.83       4469.17       4534.17
# 2       Civilian Unemployment        944.17        913.33        792.50
# 3  Civilian Unemployment Rate          0.17          0.17          0.15
# 4       Total, All Industries       2769.17       2756.67       2815.00
#
#    2013_Average  2014_Average  2015_Average  2016_Average  2017_Average  \
# 0       5175.83       5161.67       5141.67       4993.33       4803.33
# 1       4550.00       4668.33       4739.17       4640.00       4503.33
# 2        624.17        494.17        401.67        355.83        300.00
# 3          0.12          0.10          0.08          0.07          0.06
# 4       2857.50       2975.00       3038.33       3009.17       2935.83
#
#    2018_Average  2019_Average  2020_Average  2021_Average  2022_Average  \
# 0       4675.00       4645.00       4541.67       4547.50       4516.67
# 1       4405.83       4388.33       4169.17       4256.67       4303.33
# 2        268.33        255.00        373.33        288.33        211.67
# 3          0.06          0.06          0.08          0.06          0.05
# 4       2884.17       2924.17       2820.83       2903.33       2945.83
#
#    2023_Average  2024_Average
# 0       4560.00       4916.18
# 1       4300.83       4429.38
# 2        260.00        487.36
# 3          0.06          0.10
# 4       2967.50       2952.78

# %%
# Export the DataFrame to a CSV file
averaged_years_df.to_csv('Trinity_county.csv', index=False)  # Set index=False to avoid exporting the row indices
