# %%
import pandas as pd

# Load the .xls Excel file
df = pd.read_excel("Resources/ALAMEHWS.xls", engine='xlrd')

# Display the first few rows of the DataFrame
print (df)
# Out:
#     SORTORDER  BMYEAR  AREA                        INCLUDES  BREAKS  PNCO  \
# 0           1    2023     1                             NaN     NaN     1
# 1           2    2023     1                             NaN     NaN     1
# 2           3    2023     1                             NaN     NaN     1
# 3           4    2023     1                             NaN     NaN     1
# 4           8    2023     1           110000-813000, 920000     NaN     1
# 5           9    2023     1    111000-113200, 114000-115000     NaN     1
# 6          10    2023     1    113000, 210000-813000, 92000     NaN     1
# 7          11    2023     1   113000, 210000, 230000-330000     NaN     1
# 8          13    2023     1                 1133000, 210000     NaN     1
# 9          14    2023     1                   210000-330000     NaN     1
# 10         15    2023     1           321000, 327000-330000     NaN     1
# 11         16    2023     1    311000-316000, 322000-326000     NaN     1
# ...

# %%
df.head()
# Out:
#    SORTORDER  BMYEAR  AREA               INCLUDES  BREAKS  PNCO   SS-NAICS  \
# 0          1    2023     1                    NaN     NaN     1  00-000010
# 1          2    2023     1                    NaN     NaN     1  00-000020
# 2          3    2023     1                    NaN     NaN     1  00-000030
# 3          4    2023     1                    NaN     NaN     1  00-000040
# 4          8    2023     1  110000-813000, 920000     NaN     1  01-000000
#
#                         TITLE  2010-01-01 00:00:00  2010-02-01 00:00:00  ...  \
# 0        Civilian Labor Force           782200.000           782700.000  ...
# 1         Civilian Employment           691500.000           693600.000  ...
# 2       Civilian Unemployment            90700.000            89100.000  ...
# 3  Civilian Unemployment Rate                0.116                0.114  ...
# 4       Total, All Industries           648600.000           650200.000  ...
#
# ...

# %%
df.drop(['SORTORDER', 'BMYEAR', 'AREA', 'INCLUDES', 'BREAKS', 'PNCO', 'SS-NAICS'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         TITLE  2010-01-01 00:00:00  2010-02-01 00:00:00  \
# 0        Civilian Labor Force           782200.000           782700.000
# 1         Civilian Employment           691500.000           693600.000
# 2       Civilian Unemployment            90700.000            89100.000
# 3  Civilian Unemployment Rate                0.116                0.114
# 4       Total, All Industries           648600.000           650200.000
#
#    2010-03-01 00:00:00  2010-04-01 00:00:00  2010-05-01 00:00:00  \
# 0           785600.000           783700.000           779700.000
# 1           695800.000           696500.000           695500.000
# 2            89800.000            87200.000            84300.000
# 3                0.114                0.111                0.108
# 4           653900.000           653500.000           657000.000
#
#    2010-06-01 00:00:00  2010-07-01 00:00:00  2010-08-01 00:00:00  \
# 0           780600.000           785400.000           782100.000
# ...

# %%
titles_df = df["TITLE"]
titles_df
# Out:
# 0                                  Civilian Labor Force
# 1                                   Civilian Employment
# 2                                 Civilian Unemployment
# 3                            Civilian Unemployment Rate
# 4                                 Total, All Industries
# 5                                            Total Farm
# 6                                         Total Nonfarm
# 7                                       Goods Producing
# 8                      Mining, Logging and Construction
# 9                                         Manufacturing
# 10                                        Durable Goods
# 11                                     Nondurable Goods
# 12                                    Service Providing
# 13                    Trade, Transportation & Utilities
# 14                                      Wholesale Trade
# 15                                         Retail Trade
# 16            Transportation, Warehousing, and Utili...
# ...

# %%
df.head()
# Out:
#                         TITLE  2010-01-01 00:00:00  2010-02-01 00:00:00  \
# 0        Civilian Labor Force           782200.000           782700.000
# 1         Civilian Employment           691500.000           693600.000
# 2       Civilian Unemployment            90700.000            89100.000
# 3  Civilian Unemployment Rate                0.116                0.114
# 4       Total, All Industries           648600.000           650200.000
#
#    2010-03-01 00:00:00  2010-04-01 00:00:00  2010-05-01 00:00:00  \
# 0           785600.000           783700.000           779700.000
# 1           695800.000           696500.000           695500.000
# 2            89800.000            87200.000            84300.000
# 3                0.114                0.111                0.108
# 4           653900.000           653500.000           657000.000
#
#    2010-06-01 00:00:00  2010-07-01 00:00:00  2010-08-01 00:00:00  \
# 0           780600.000           785400.000           782100.000
# ...

# %%
print(df.columns)
# Out:
# Index([            'TITLE', 2010-01-01 00:00:00, 2010-02-01 00:00:00,
#        2010-03-01 00:00:00, 2010-04-01 00:00:00, 2010-05-01 00:00:00,
#        2010-06-01 00:00:00, 2010-07-01 00:00:00, 2010-08-01 00:00:00,
#        2010-09-01 00:00:00,
#        ...
#        2023-10-01 00:00:00, 2023-11-01 00:00:00, 2023-12-01 00:00:00,
#        2024-01-01 00:00:00, 2024-02-01 00:00:00, 2024-03-01 00:00:00,
#        2024-04-01 00:00:00, 2024-05-01 00:00:00, 2024-06-01 00:00:00,
#        2024-07-01 00:00:00],
#       dtype='object', length=176)

# %%
# Select the portion of the DataFrame from column 2 and row 2 onwards
data_subset = df.iloc[1:, 1:].apply(pd.to_numeric, errors='coerce').fillna(0).astype(int)

# Update the original DataFrame with the formatted data
df.iloc[1:, 1:] = data_subset

df.head()
# Out:
#                       TITLE 2010-01-01 2010-02-01 2010-03-01 2010-04-01  \
# 0      Civilian Labor Force   782200.0   782700.0   785600.0   783700.0
# 1                         0     691500     693600     695800     696500
# 2    Civilian Unemployment%          0          0          0          0
# 3                         0          0          0          0          0
# 4                         0     648600     650200     653900     653500
#
#   2010-05-01 2010-06-01 2010-07-01 2010-08-01 2010-09-01  ... 2023-10-01  \
# 0   779700.0   780600.0   785400.0   782100.0   786000.0  ...   828700.0
# 1     695500     693000     694900     692400     700100  ...     790700
# 2          0          0          0          0          0  ...          0
# 3          0          0          0          0          0  ...          0
# 4     657000     657900     644700     641900     654600  ...     817800
#
#   2023-11-01 2023-12-01 2024-01-01 2024-02-01 2024-03-01 2024-04-01  \
# ...
