# %%
import pandas as pd

# %%
avg_cost_by_county = pd.read_csv('../data/avg_cost_by_county.csv')

# %%
avg_cost_by_county.head()
# Out:
#    RegionID  SizeRank          RegionName State      1/31/2004      2/29/2004  \
# 0      3101         0  Los Angeles County    CA  359637.887854  365587.644879
# 1       139         1         Cook County    IL  212183.381348  213545.681301
# 2      1090         2       Harris County    TX  121818.012379  122617.363618
# 3      2402         3     Maricopa County    AZ  177405.207211  178222.959316
# 4      2841         4    San Diego County    CA  398657.715678  404627.790326
#
#        3/31/2004      4/30/2004      5/31/2004      6/30/2004  ...  \
# 0  371964.449058  379899.180522  389740.328886  399902.550401  ...
# 1  214699.864000  216016.957799  217640.336495  219517.627537  ...
# 2  124111.219107  125504.882549  126877.064356  127403.928382  ...
# 3  179257.984336  180538.524221  182116.180357  183826.754819  ...
# 4  413281.930706  421490.824884  429782.054434  442327.588370  ...
#
#       10/31/2023     11/30/2023     12/31/2023      1/31/2024      2/29/2024  \
# ...
