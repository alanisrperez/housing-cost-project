# %%
## INDUSTRY BY COUNTY DATA - Alanis Perez

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as num

# Ignore all warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# YUBA COUNTY
yuba_data_path = "data/Yuba_county.csv"
yuba_data = pd.read_csv(yuba_data_path)

# %%
yuba_data.head()
# Out:
#    SORTORDER         TITLE - YUBA COUNTY  10-Jan  10-Feb  10-Mar  10-Apr  \
# 0          1        Civilian Labor Force  74,000  75,200  75,500  75,200
# 1          2         Civilian Employment  59,400  59,600  60,000  60,900
# 2          3       Civilian Unemployment  14,600  15,600  15,500  14,300
# 3          4  Civilian Unemployment Rate  19.70%  20.70%  20.50%  19.10%
# 4          8       Total, All Industries  40,000  40,100  40,700  41,600
#
#    10-May  10-Jun  10-Jul  10-Aug  ...  23-Dec 2023_Data  24-Jan  24-Feb  \
# 0  75,600  75,700  75,600  76,900  ...  78,900   943,400  79,600  80,000
# 1  61,700  61,700  61,900  64,100  ...  72,600   874,200  72,200  72,200
# 2  13,900  13,900  13,700  12,900  ...   6,300    69,400   7,400   7,900
# 3  18.30%  18.40%  18.10%  16.70%  ...   8.00%     7.34%   9.30%   9.80%
# 4  42,900  43,300  42,900  45,500  ...  56,000   664,100  54,300  54,500
#
#    24-Mar  24-Apr  24-May  24-Jun  24-Jul 2024_Data
# ...

# %%
yuba_df = yuba_data[['TITLE - YUBA COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
yuba_df.head(10)
# Out:
#                       TITLE - YUBA COUNTY 2010_Data 2011_Data 2012_Data  \
# 0                    Civilian Labor Force   902,800   898,500   891,900
# 1                     Civilian Employment   735,300   736,700   744,500
# 2                   Civilian Unemployment   167,600   161,500   147,200
# 3              Civilian Unemployment Rate    18.54%    18.00%    16.49%
# 4                   Total, All Industries   508,400   508,900   514,100
# 5                              Total Farm    55,300    56,400    55,600
# 6                           Total Nonfarm   453,100   452,500   458,500
# 7                           Total Private   327,400   327,200   335,000
# 8                         Goods Producing    44,900    44,200    43,700
# 9        Mining, Logging and Construction    20,800    19,300    18,000
#
#   2013_Data 2014_Data 2015_Data 2016_Data 2017_Data 2018_Data 2019_Data  \
# 0   874,100   865,100   869,600   877,700   884,200   889,100   902,600
# ...

# %%
yuba_industries = yuba_df['TITLE - YUBA COUNTY'].unique()
print(yuba_industries)
# Out:
# ['Civilian Labor Force' '  Civilian Employment' '  Civilian Unemployment'
#  'Civilian Unemployment Rate' 'Total, All Industries' '  Total Farm'
#  'Total Nonfarm' '    Total Private' '    Goods Producing'
#  '      Mining, Logging and Construction' '      Manufacturing'
#  'Service-Providing' '    Private Service Providing'
#  '      Trade, Transportation, and Utilities' '        Wholesale Trade'
#  '        Retail Trade'
#  '        Transportation, Warehousing, and Utilities' '      Information'
#  '      Financial Activities' '      Professional and Business Services'
#  '      Private Education and Health Services'
#  '      Leisure and Hospitality' '      Other Services' '      Government'
#  '        Federal Government' '        Total State and Local Government'
#  '          State Government' '          Local Government'
#  '          Local Government excluding Educational Services'
#  '               Special Districts plus Tribes']

# %%
# Biggest industries in Yuba

# %%
# YOLO COUNTY
yolo_data_path = "data/Yolo_county.csv"
yolo_data = pd.read_csv(yolo_data_path)

# %%
yolo_data.head()
# Out:
#    SORTORDER         TITLE - YOLO COUNTY     10-Jan     10-Feb     10-Mar  \
# 0          1        Civilian Labor Force  1,053,400  1,054,400  1,056,400
# 1          2         Civilian Employment    914,400    916,400    918,400
# 2          3       Civilian Unemployment    139,000    137,900    138,100
# 3          4  Civilian Unemployment Rate     13.20%     13.10%     13.10%
# 4          8       Total, All Industries    834,100    834,000    837,400
#
#       10-Apr     10-May     10-Jun     10-Jul     10-Aug  ...     23-Dec  \
# 0  1,051,400  1,048,300  1,050,100  1,058,300  1,052,900  ...  1,132,100
# 1    921,000    921,800    918,200    922,600    919,900  ...  1,080,000
# 2    130,300    126,600    131,800    135,700    133,000  ...     52,100
# 3     12.40%     12.10%     12.60%     12.80%     12.60%  ...      4.60%
# 4    842,400    849,700    851,500    838,800    836,400  ...  1,104,400
#
#     2023_Data     24-Jan     24-Feb     24-Mar     24-Apr     24-May  \
# ...

# %%
yolo_df = yolo_data[['TITLE - YOLO COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
yolo_df.head(10)
# Out:
#                       TITLE - YOLO COUNTY   2010_Data   2011_Data   2012_Data  \
# 0                    Civilian Labor Force  12,608,700  12,523,800  12,548,000
# 1                     Civilian Employment  11,012,800  11,015,800  11,233,400
# 2                   Civilian Unemployment   1,595,800   1,508,000   1,314,500
# 3              Civilian Unemployment Rate      12.66%      12.03%      10.47%
# 4                   Total, All Industries  10,083,900  10,058,100  10,278,000
# 5                              Total Farm      96,600      98,400     103,400
# 6                           Total Nonfarm   9,987,300   9,959,700  10,174,600
# 7                           Total Private   7,224,200   7,264,600   7,516,600
# 8                         Goods Producing     860,000     847,300     873,300
# 9       Mining, Logging, and Construction     466,400     448,800     466,600
#
#     2013_Data   2014_Data   2015_Data   2016_Data   2017_Data   2018_Data  \
# ...

# %%
yolo_industries = yolo_df['TITLE - YOLO COUNTY'].unique()
print(yolo_industries)
# Out:
# ['Civilian Labor Force' '  Civilian Employment' '  Civilian Unemployment'
#  'Civilian Unemployment Rate' 'Total, All Industries' '     Total Farm'
#  '  Total Nonfarm' '    Total Private' '    Goods Producing'
#  '     Mining, Logging, and Construction' '      Mining and Logging'
#  '      Construction' '        Construction of Buildings'
#  '        Specialty Trade Contractors'
#  '            Foundation, Structure, and Building Exterior Co'
#  '          Building Equipment Contractors'
#  '          Building Finishing Contractors' '      Manufacturing'
#  '        Durable Goods'
#  '          Computer and Electronic Product Manufacturing'
#  '        Non-Durable Goods' '          Food Manufacturing'
#  '     Service-Providing' '    Private Service Providing'
#  '     Trade, Transportation, and Utilities' '        Wholesale Trade'
#  '          Merchant Wholesalers, Durable Goods'
#  '          Merchant Wholesalers, Nondurable Goods' '        Retail Trade'
# ...

# %%
# Biggest industries in Yolo

# %%
# VENTURA COUNTY
ventura_data_path = "data/Ventura_county.csv"
ventura_data = pd.read_csv(ventura_data_path)

# %%
ventura_data.head()
# Out:
#   SORTORDER      TITLE - VENTURA COUNTY   Jan-10   Feb-10   Mar-10   Apr-10  \
# 0         1        Civilian Labor Force  426,900  429,200  431,200  435,400
# 1         2         Civilian Employment  376,900  380,400  382,500  389,300
# 2         3       Civilian Unemployment   50,000   48,800   48,800   46,000
# 3   400.00%  Civilian Unemployment Rate   11.70%   11.40%   11.30%   10.60%
# 4         8       Total, All Industries  292,700  295,500  298,400  307,000
#
#     May-10   Jun-10   Jul-10   Aug-10  ...   Dec-23 2023_Data   Jan-24  \
# 0  434,000  429,300  430,400  427,900  ...  411,200   412,933  413,500
# 1  389,100  382,600  380,800  378,400  ...  391,600   395,283  392,000
# 2   44,900   46,700   49,600   49,500  ...   19,700    17,650   21,500
# 3   10.30%   10.90%   11.50%   11.60%  ...    4.80%     4.28%    5.20%
# 4  309,900  304,900  297,000  295,000  ...  340,900   338,083  335,000
#
#     Feb-24   Mar-24   Apr-24   May-24   Jun-24   Jul-24 2024_Data
# ...

# %%
ventura_df = ventura_data[['TITLE - VENTURA COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
ventura_df.head(10)
# Out:
#                    TITLE - VENTURA COUNTY 2010_Data 2011_Data 2012_Data  \
# 0                    Civilian Labor Force   430,225   430,908   433,675
# 1                     Civilian Employment   382,450   385,958   393,575
# 2                   Civilian Unemployment    47,783    44,950    40,100
# 3              Civilian Unemployment Rate    11.11%    10.43%     9.24%
# 4                   Total, All Industries   300,533   303,250   309,958
# 5                              Total Farm    24,433    25,242    27,092
# 6                           Total Nonfarm   276,100   278,008   282,867
# 7                           Total Private   231,892   233,608   239,242
# 8                         Goods Producing    38,100    37,292    37,242
# 9        Mining, Logging and Construction    12,508    12,567    13,050
#
#   2013_Data 2014_Data 2015_Data 2016_Data 2017_Data 2018_Data 2019_Data  \
# 0   432,350   429,175   427,233   425,333   423,675   423,092   421,542
# ...

# %%
ventura_industries = ventura_df['TITLE - VENTURA COUNTY'].unique()
print(ventura_industries)
# Out:
# ['Civilian Labor Force' '  Civilian Employment' '  Civilian Unemployment'
#  'Civilian Unemployment Rate' 'Total, All Industries' '  Total Farm'
#  '  Total Nonfarm' '    Total Private' '    Goods Producing'
#  '      Mining, Logging and Construction' '      Mining and Logging'
#  '      Construction' '        Specialty Trade Contractors'
#  '      Manufacturing' '        Durable Goods'
#  '          Computer and Electronic Product Manufacturing'
#  '        Non-Durable Goods' '          Chemical Manufacturing'
#  'Service-Providing' '    Private Service Providing'
#  '      Trade, Transportation, and Utilities' '        Wholesale Trade'
#  '        Retail Trade' '          Food and Beverage Retailers'
#  '          General Merchandise Retailers'
#  '          Clothing, Clothing Accessories, Shoe, and Jewelry '
#  '        Transportation, Warehousing, and Utilities'
#  '           Transportation and Warehousing' '      Information'
# ...

# %%
# Biggest industries in Ventura

# %%
# TUOLUMNE COUNTY
tuolumne_data_path = "data/Tuolumne_county.csv"
tuolumne_data = pd.read_csv(tuolumne_data_path)

# %%
tuolumne_data.head()
# Out:
#   SORTORDER     TITLE - TUOLUMNE COUNTY  Jan-10  Feb-10  Mar-10  Apr-10  \
# 0         1        Civilian Labor Force  22,470  22,750  22,670  22,540
# 1         2         Civilian Employment  18,660  18,890  18,740  18,900
# 2         3       Civilian Unemployment   3,820   3,870   3,930   3,640
# 3   400.00%  Civilian Unemployment Rate  17.00%  17.00%  17.30%  16.20%
# 4         8       Total, All Industries  15,540  15,670  15,560  15,730
#
#    May-10  Jun-10  Jul-10  Aug-10  ...  Dec-23 2023_Data  Jan-24  Feb-24  \
# 0  22,700  22,720  23,020  23,000  ...  19,890    19,979  20,010  20,300
# 1  19,250  19,340  19,600  19,600  ...  18,860    18,979  18,780  19,010
# 2   3,450   3,390   3,420   3,400  ...   1,030     1,001   1,230   1,290
# 3  15.20%  14.90%  14.90%  14.80%  ...   5.20%     5.01%   6.20%   6.30%
# 4  16,220  16,420  16,370  16,430  ...  17,870    17,611  17,480  17,660
#
#    Mar-24  Apr-24  May-24  Jun-24  Jul-24 2024_Data
# ...

# %%
tuolumne_df = tuolumne_data[['TITLE - TUOLUMNE COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
tuolumne_df.head(10)
# Out:
#                  TITLE - TUOLUMNE COUNTY 2010_Data 2011_Data 2012_Data  \
# 0                   Civilian Labor Force    22,658    22,702    22,279
# 1                    Civilian Employment    19,125    19,363    19,341
# 2                  Civilian Unemployment     3,533     3,338     2,939
# 3             Civilian Unemployment Rate    15.61%    14.73%    13.17%
# 4                  Total, All Industries    16,043    16,302    16,318
# 5                             Total Farm        61        59        50
# 6                          Total Nonfarm    15,982    16,243    16,268
# 7                          Total Private    10,667    11,070    11,033
# 8                        Goods Producing     1,344     1,493     1,454
# 9       Mining, Logging and Construction       665       663       626
#
#   2013_Data 2014_Data 2015_Data 2016_Data 2017_Data 2018_Data 2019_Data  \
# 0    21,678    21,537    21,533    21,568    21,369    21,188    20,938
# ...

# %%
tuolumne_industries = tuolumne_df['TITLE - TUOLUMNE COUNTY'].unique()
print(tuolumne_industries)
# Out:
# ['Civilian Labor Force' '  Civilian Employment' '  Civilian Unemployment'
#  'Civilian Unemployment Rate' 'Total, All Industries' '  Total Farm'
#  '  Total Nonfarm' '    Total Private' '    Goods Producing'
#  '     Mining, Logging and Construction' '      Mining and Logging'
#  '      Construction' '      Manufacturing' '        Durable Goods'
#  '       Non-Durable Goods' '    Service-Providing'
#  '    Private Service Providing' '      Trade, Transportation & Utilities'
#  '        Wholesale Trade' '        Retail Trade'
#  '        Transportation, Warehousing, and Utilities' '      Information'
#  '      Financial Activities' '      Professional and Business Services'
#  '      Private Education and Health Services'
#  '      Leisure and Hospitality' '      Other Services' '      Government'
#  '        Federal Government' '        State & Local Government'
#  '          State Government' '          Local Government']

# %%
# Biggest industries in Tuolumne

# %%
# TULARE COUNTY
tulare_data_path = "data/tulare_county.csv"
tulare_data = pd.read_csv(tulare_data_path)

# %%
tulare_data.head()
# Out:
#   SORTORDER       TITLE - TULARE COUNTY   Jan-10   Feb-10   Mar-10   Apr-10  \
# 0         1        Civilian Labor Force  202,700  202,400  199,000  203,500
# 1         2         Civilian Employment  164,000  162,700  159,100  168,100
# 2         3       Civilian Unemployment   38,700   39,700   39,900   35,400
# 3   400.00%  Civilian Unemployment Rate   19.10%   19.60%   20.00%   17.40%
# 4         8       Total, All Industries  139,800  138,300  134,800  145,500
#
#     May-10   Jun-10   Jul-10   Aug-10  ...   Dec-23 2023_Data   Jan-24  \
# 0  207,900  206,800  202,100  204,700  ...  214,500   213,308  215,500
# 1  174,600  173,100  166,500  170,900  ...  191,000   191,975  190,000
# 2   33,300   33,700   35,600   33,800  ...   23,500    21,325   25,500
# 3   16.00%   16.30%   17.60%   16.50%  ...   10.90%     9.99%   11.80%
# 4  154,800  155,400  145,100  150,400  ...  181,000   178,875  175,200
#
#     Feb-24   Mar-24   Apr-24   May-24   Jun-24   Jul-24 2024_Data
# ...

# %%
tulare_df = tulare_data[['TITLE - TULARE COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
tulare_df.head(10)
# Out:
#                      TITLE - TULARE COUNTY 2010_Data 2011_Data 2012_Data  \
# 0                     Civilian Labor Force   203,492   203,383   201,067
# 1                      Civilian Employment   167,683   168,033   168,075
# 2                    Civilian Unemployment    35,800    35,375    32,992
# 3               Civilian Unemployment Rate    17.59%    17.40%    16.39%
# 4                    Total, All Industries   146,242   146,117   145,317
# 5                               Total Farm    37,933    37,125    34,492
# 6                            Total Nonfarm   108,308   108,992   110,825
# 7                            Total Private    77,267    78,367    80,242
# 8                          Goods Producing    14,983    15,092    15,367
# 9        Mining, Logging, and Construction     3,933     3,908     4,033
#
#   2013_Data 2014_Data 2015_Data 2016_Data 2017_Data 2018_Data 2019_Data  \
# 0   200,500   197,900   202,125   203,317   204,458   202,992   202,133
# ...

# %%
tulare_industries = tulare_df['TITLE - TULARE COUNTY'].unique()
print(tulare_industries)
# Out:
# ['Civilian Labor Force' '  Civilian Employment' '  Civilian Unemployment'
#  'Civilian Unemployment Rate' 'Total, All Industries' '  Total Farm'
#  '     Total Nonfarm' '    Total Private' '    Goods Producing'
#  '      Mining, Logging, and Construction' '      Manufacturing'
#  '        Durable Goods' '        Non-Durable Goods'
#  '          Food Manufacturing' '     Service-Providing'
#  '    Private Service Providing'
#  '     Trade, Transportation, and Utilities' '        Wholesale Trade'
#  '        Retail Trade'
#  '        Transportation, Warehousing, and Utilities' '      Information'
#  '      Financial Activities' '        Finance and Insurance'
#  '      Professional and Business Services'
#  '      Private Education and Health Services'
#  '      Leisure and Hospitality'
#  '         Arts, Entertainment, and Recreation'
#  '        Accommodation and Food Services' '          Accommodation'
#  '          Food Services and Drinking Places' '      Other Services'
# ...

# %%
# Biggest industries in Tulare

# %%
# TRINITY COUNTY
trinity_data_path = "data/trinity_county.csv"
trinity_data = pd.read_csv(trinity_data_path)

# %%
trinity_data.head()
# Out:
#   SORTORDER      TITLE - TRINITY COUNTY  Jan-10  Feb-10  Mar-10  Apr-10  \
# 0         1        Civilian Labor Force   5,250   5,320   5,360   5,360
# 1         2         Civilian Employment   4,150   4,200   4,280   4,370
# 2         3       Civilian Unemployment   1,090   1,120   1,070     990
# 3   400.00%  Civilian Unemployment Rate  20.80%  21.00%  20.00%  18.50%
# 4         8       Total, All Industries   2,520   2,540   2,590   2,660
#
#    May-10  Jun-10  Jul-10  Aug-10  ... Dec-23 2023_Data Jan-24 Feb-24 Mar-24  \
# 0   5,450   5,660   5,630   5,660  ...  4,510     4,560  4,530  4,600  4,650
# 1   4,570   4,790   4,760   4,840  ...  4,250     4,301  4,180  4,250  4,310
# 2     880     870     860     820  ...    270       260    350    360    330
# 3  16.20%  15.40%  15.30%  14.50%  ...  5.90%     5.68%  7.60%  7.80%  7.20%
# 4   2,830   3,000   2,940   3,010  ...  2,990     2,968  2,880  2,930  2,970
#
#   Apr-24 May-24 Jun-24 Jul-24 2024_Data
# ...

# %%
trinity_df = trinity_data[['TITLE - TRINITY COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
trinity_df.head(10)

# %%
trinity_industries = trinity_df['TITLE - TRINITY COUNTY'].unique()
print(trinity_industries)

# %%
# Biggest industries in Trinity

# %%
# TEHAMA COUNTY
tehama_data_path = "data/Tehama_county.csv"
tehama_data = pd.read_csv(tehama_data_path)

# %%
tehama_data.head()

# %%
tehama_df = tehama_data[['TITLE - TEHAMA COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
tehama_df.head(10)

# %%
tehama_industries = tehama_df['TITLE - TEHAMA COUNTY'].unique()
print(tehama_industries)

# %%
# Biggest industries in Tehama

# %%
# SUTTER COUNTY
sutter_data_path = "data/Sutter_county.csv"
sutter_data = pd.read_csv(sutter_data_path)

# %%
sutter_data.head()

# %%
sutter_df = sutter_data[['TITLE - SUTTER COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
sutter_df.head(10)

# %%
sutter_industries = sutter_df['TITLE - SUTTER COUNTY'].unique()
print(sutter_industries)

# %%
# Biggest industries in Sutter

# %%
# STANISLAUS COUNTY
stanislaus_data_path = "data/Stanislaus_county.csv"
stanislaus_data = pd.read_csv(stanislaus_data_path)

# %%
stanislaus_data.head()

# %%
stanislaus_df = stanislaus_data[['TITLE - STANISLAUS COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
stanislaus_df.head(10)

# %%
stanislaus_industries = stanislaus_df['TITLE - STANISLAUS COUNTY'].unique()
print(stanislaus_industries)

# %%
# Biggest industries in Stanislaus

# %%
# SONOMA COUNTY
sonoma_data_path = "data/Sonoma_county.csv"
sonoma_data = pd.read_csv(sonoma_data_path)

# %%
sonoma_data.head()

# %%
sonoma_df = sonoma_data[['TITLE - SONOMA COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
sonoma_df.head(10)

# %%
sonoma_industries = sonoma_df['TITLE - SONOMA COUNTY'].unique()
print(sonoma_industries)

# %%
# Biggest industries in Sonoma

# %%
# SOLANO COUNTY
solano_data_path = "data/Solano_county.csv"
solano_data = pd.read_csv(solano_data_path)

# %%
solano_data.head()

# %%
solano_df = solano_data[['TITLE - SOLANO COUNTY', '2010_Data', '2011_Data', '2012_Data', '2013_Data',
                     '2014_Data', '2015_Data', '2016_Data', '2017_Data', '2018_Data', '2019_Data',
                     '2020_Data', '2021_Data', '2022_Data', '2023_Data','2024_Data']]
solano_df.head(10)

# %%
solano_industries = solano_df['TITLE - SOLANO COUNTY'].unique()
print(solano_industries)

# %%
# Biggest industries in Solano
